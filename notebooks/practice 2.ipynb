# %%
import numpy as np
b=np.array([1,2,3,4,5])

# %%
b
# Out:
# array([1, 2, 3, 4, 5])

# %%
b[0]
# Out:
# np.int64(1)

# %%
b[-4:-1]
# Out:
# array([2, 3, 4])

# %%
b[[0,1,-1]]
# Out:
# array([1, 2, 5])

# %%
a=np.array([1,2,3,4])
a.dtype
# Out:
# dtype('int64')

# %%
b=np.array([
                   [1,2,3],
                   [5,6,7]
                  ])

# %%
b.shape
# Out:
# (2, 3)

# %%
b.ndim
# Out:
# 2

# %%
b.size
# Out:
# 6

# %%
t=np.arange(4)

# %%
t
# Out:
# array([0, 1, 2, 3])

# %%
t[[0,-2]]
# Out:
# array([0, 2])

# %%
t.mean()
t[t>t.mean()]
# Out:
# array([2, 3])

# %%
u=np.arange(4)
u
# Out:
# array([0, 1, 2, 3])

# %%
u[( u > u.mean() ) & u%2 == 0 ]
# Out:
# array([0, 1, 2])

# %%
import pandas as pd
import numpy as np

# %%
u=pd.Series([5.43,6.21,4.56,1.23,9.65])
u
# Out:
# 0    5.43
# 1    6.21
# 2    4.56
# 3    1.23
# 4    9.65
# dtype: float64

# %%
u.name='practice with pandas'
u.values
# Out:
# array([5.43, 6.21, 4.56, 1.23, 9.65])

# %%
t=pd.Series(np.random.rand(5),index=['a','b','c','d','e'])
t
# Out:
# a    0.417355
# b    0.565487
# c    0.001596
# d    0.054470
# e    0.704694
# dtype: float64

# %%
type(t.values)
# Out:
# numpy.ndarray

# %%
t[0]
# Out:
# /tmp/ipykernel_4533/1412434764.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t[0]
# np.float64(0.41735495971109704)

# %%
t.index
u.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
p=pd.Series([1,2,3,4,5],index=['ind','pak','oma','chn','rus'])
p
# Out:
# ind    1
# pak    2
# oma    3
# chn    4
# rus    5
# dtype: int64

# %%
p['ind']
# Out:
# np.int64(1)

# %%
import numpy as np
import pandas as pd
batpi=pd.Series([1.6,1.3,0.9,1.8,1.5,2.2,2.5],index=['09:01','09:02','09:03','09:04','09:05','09:06','09:07'])

# %%
batpi.name='Current sensor reading'

# %%
batpi
# Out:
# 09:01    1.6
# 09:02    1.3
# 09:03    0.9
# 09:04    1.8
# 09:05    1.5
# 09:06    2.2
# 09:07    2.5
# Name: Current sensor reading, dtype: float64

# %%
batpi > 1.3
# Out:
# 09:01     True
# 09:02    False
# 09:03    False
# 09:04     True
# 09:05     True
# 09:06     True
# 09:07     True
# Name: Current sensor reading, dtype: bool

# %%
batpi[batpi>1.3]
# Out:
# 09:01    1.6
# 09:04    1.8
# 09:05    1.5
# 09:06    2.2
# 09:07    2.5
# Name: Current sensor reading, dtype: float64

# %%
t=batpi.mean()
t
# Out:
# np.float64(1.6857142857142857)

# %%
batpi[~(batpi>t)]
# Out:
# 09:01    1.6
# 09:02    1.3
# 09:03    0.9
# 09:05    1.5
# Name: Current sensor reading, dtype: float64

# %%
np.log(batpi)
# Out:
# 09:01    0.470004
# 09:02    0.262364
# 09:03   -0.105361
# 09:04    0.587787
# 09:05    0.405465
# 09:06    0.788457
# 09:07    0.916291
# Name: Current sensor reading, dtype: float64

# %%
batpi[batpi>batpi.mean()].mean()
# Out:
# np.float64(2.1666666666666665)

# %%
import pandas as pd

# Create a simple DataFrame
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva"],
    "Age": [24, 27, 22, 32, 29],
    "City": ["New York", "Los Angeles", "Chicago", "Houston", "Phoenix"],
    "Score": [85, 90, 78, 92, 88]
}

df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age         City  Score
# 0    Alice   24     New York     85
# 1      Bob   27  Los Angeles     90
# 2  Charlie   22      Chicago     78
# 3    David   32      Houston     92
# 4      Eva   29      Phoenix     88

# %%
df.index=['one','two','three','four','five']
df
# Out:
#           Name  Age         City  Score
# one      Alice   24     New York     85
# two        Bob   27  Los Angeles     90
# three  Charlie   22      Chicago     78
# four     David   32      Houston     92
# five       Eva   29      Phoenix     88

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City', 'Score'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, one to five
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   City    5 non-null      object
#  3   Score   5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 200.0+ bytes

# %%
df.size
# Out:
# 20

# %%
df.shape
# Out:
# (5, 4)

# %%
df.dtypes
# Out:
# Name     object
# Age       int64
# City     object
# Score     int64
# dtype: object

# %%
df
# Out:
#           Name  Age         City  Score
# one      Alice   24     New York     85
# two        Bob   27  Los Angeles     90
# three  Charlie   22      Chicago     78
# four     David   32      Houston     92
# five       Eva   29      Phoenix     88

# %%
df.iloc[1:3,[0,1,2,3]]
# Out:
#           Name  Age         City  Score
# two        Bob   27  Los Angeles     90
# three  Charlie   22      Chicago     78

# %%
df.loc['two':'four','Age']
# Out:
# two      27
# three    22
# four     32
# Name: Age, dtype: int64

# %%
df
# Out:
#           Name  Age         City  Score
# one      Alice   24     New York     85
# two        Bob   27  Los Angeles     90
# three  Charlie   22      Chicago     78
# four     David   32      Houston     92
# five       Eva   29      Phoenix     88

# %%
df['Age']>25
# Out:
# one      False
# two       True
# three    False
# four      True
# five      True
# Name: Age, dtype: bool

# %%
df.loc[df['Age']>25]
# Out:
#        Name  Age         City  Score
# two     Bob   27  Los Angeles     90
# four  David   32      Houston     92
# five    Eva   29      Phoenix     88

# %%
import pandas as pd
pin=pd.Series([23,84,13])

# %%
df['pincode']=pin

# %%
df
# Out:
#       Name  Age         City  Score  pincode
# 0    Alice   24     New York     85     23.0
# 1      Bob   27  Los Angeles     90     84.0
# 2  Charlie   22      Chicago     78     13.0
# 3    David   32      Houston     92      NaN
# 4      Eva   29      Phoenix     88      NaN

# %%
df[["Name", "Age"]]
# Out:
#       Name  Age
# 0    Alice   24
# 1      Bob   27
# 2  Charlie   22
# 3    David   32
# 4      Eva   29

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("/home/batpi/Downloads/battylytics_mock_with_anomalies.csv",index_col=0,parse_dates=True)

# %%
df.head()
# Out:
#                      Voltage_V  Current_A  Temperature_C  State_of_Charge_%  \
# Timestamp
# 2025-09-01 09:00:00      3.575      0.447          22.44               51.1
# 2025-09-01 09:01:00      4.151     -1.442          29.90               41.7
# 2025-09-01 09:02:00      3.932     -0.831          20.69               86.3
# 2025-09-01 09:03:00      2.300     -0.535          38.19               48.5
# 2025-09-01 09:04:00      3.356     -0.176          25.18               42.5
#
#                      State_of_Health_%  Anomaly
# Timestamp
# 2025-09-01 09:00:00               95.9    False
# 2025-09-01 09:01:00               88.7    False
# 2025-09-01 09:02:00               79.9    False
# 2025-09-01 09:03:00               71.9     True
# 2025-09-01 09:04:00               79.3    False

# %%
df.shape
# Out:
# (20, 7)

# %%
df.dtypes
# Out:
# Timestamp             object
# Voltage_V            float64
# Current_A            float64
# Temperature_C        float64
# State_of_Charge_%    float64
# State_of_Health_%    float64
# Anomaly                 bool
# dtype: object

# %%
df['Timestamp']=pd.to_datetime(df['Timestamp'])

# %%
df
# Out:
#              Timestamp  Voltage_V  Current_A  Temperature_C  \
# 0  2025-09-01 09:00:00      3.575      0.447          22.44
# 1  2025-09-01 09:01:00      4.151     -1.442          29.90
# 2  2025-09-01 09:02:00      3.932     -0.831          20.69
# 3  2025-09-01 09:03:00      2.300     -0.535          38.19
# 4  2025-09-01 09:04:00      3.356     -0.176          25.18
# 5  2025-09-01 09:05:00      3.356      1.141          33.25
# 6  2025-09-01 09:06:00      3.258     -1.201          26.23
# 7  2025-09-01 09:07:00      4.066      0.057          75.20
# 8  2025-09-01 09:08:00      3.801      0.370          30.93
# 9  2025-09-01 09:09:00      3.908     -1.814          23.70
# 10 2025-09-01 09:10:00      3.221      0.430          39.39
# 11 2025-09-01 09:11:00      4.170     -1.318          35.50
# 12 2025-09-01 09:12:00      4.032     -7.500          38.79
# 13 2025-09-01 09:13:00      3.412      1.796          37.90
# 14 2025-09-01 09:14:00      3.382      1.863          31.96
# ...

# %%
df.iloc[1]
# Out:
# Voltage_V            4.151
# Current_A           -1.442
# Temperature_C         29.9
# State_of_Charge_%     41.7
# State_of_Health_%     88.7
# Anomaly              False
# Name: 2025-09-01 09:01:00, dtype: object

# %%
df.plot()
# Out:
# <Axes: xlabel='Timestamp'>

# %%
import numpy as np
import pandas as pd
np.nan
# Out:
# nan

# %%
s=pd.Series([1,2,3,4,np.nan,5])
s
s.mean()
s.fillna(s.mean())
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    3.0
# 5    5.0
# dtype: float64
