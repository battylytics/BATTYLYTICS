# %%
# !which python

# %%
import sys
print(sys.getsizeof(5))
# Out:
# 28

# %%
print("Bajji is a good boy")
# Out:
# Bajji is a good boy

# %%
import numpy as np
a=np.array({1,2,3,4})
print(a)
# Out:
# {1, 2, 3, 4}

# %%
b=np.array([1,2,3,4,55,])
